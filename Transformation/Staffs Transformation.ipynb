# %%
import pandas as pd
import os

# %%
staffs = pd.read_csv('../staging_1/staffs/staffs.csv')
staffs
# Out:
#    staff_id  first_name last_name                          email  \
# 0         2      Mireya       NaN     mireya.copeland@bikes.shop
# 1         3       Genna   Serrano       genna.serrano@bikes.shop
# 2         4      Virgie   Wiggins      virgie.wiggins@bikes.shop
# 3         5    Jannette     David      jannette.david@bikes.shop
# 4         6   Marcelene     Boyer                            NaN
# 5         7      Venita    Daniel       venita.daniel@bikes.shop
# 6         8        Kali    Vargas         kali.vargas@bikes.shop
# 7         9       Layla   Terrell       layla.terrell@bikes.shop
# 8        10  Bernardine   Houston  bernardine.houston@bikes.shop
#
#             phone  active  store_id  manager_id source  \
# 0  (831) 555-5555       1       1.0         1.0     DL
# 1  (831) 555-5556       1       1.0         2.0     DL
# 2  (831) 555-5557       1       1.0         2.0     DL
# 3  (516) 379-4444       1       2.0         1.0     DL
# ...

# %%
file_path = '../Staging_2/Staffs/staffs.csv'

os.makedirs(os.path.dirname(file_path), exist_ok=True)
staffs.to_csv(file_path, index = False)
